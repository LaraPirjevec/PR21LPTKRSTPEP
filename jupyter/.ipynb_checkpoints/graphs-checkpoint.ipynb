# %% [markdown]
# Razlicni grafi za seminarsko 2022
# Za pretvorbo med alkoholom v izdihanem zraku in v krvi se uporablja 2,083.
# https://www.utoledo.edu/studentaffairs/counseling/selfhelp/substanceuse/bac.html, ponuja vrednost 1 : 2100, vendar je legalna meja 0,5 g/kg krvi oziroma 0,24 mg/l, v izdihanem zraku. Koeficient je torej 2.083.

# %%
#init code
import math
import numpy as np
import matplotlib.pyplot as plt
from csv import DictReader
from PIL import Image
import random

data = []
for year in range(2011, 2021):
    data += list(DictReader(open(f'../data/pn{year}.csv', 'rt', encoding='utf-8'), delimiter=";"))

for row in data:
    row["VrednostAlkotesta"] = row["VrednostAlkotesta"].replace(",", ".")
    row["VrednostStrokovnegaPregleda"] = row["VrednostStrokovnegaPregleda"].replace(",", ".")


def create_geo_array():
    latitudes = []
    longitudes = []
    for row in data:
        latitude = float(row["GeoKoordinataX"])
        longitude = float(row["GeoKoordinataY"])
        if (longitude == 0.0 or latitude == 0.0):
            continue
        latitudes.append(float(row["GeoKoordinataX"]))
        longitudes.append(float(row["GeoKoordinataY"]))
    return np.array([latitudes, longitudes])


df_geo = create_geo_array()

def qulify_accident(amounts_dict, key, row):
    item = amounts_dict[key]
    item = (item[0] + 1, item[1], item[2])
    if (row["KlasifikacijaNesrece"] == "S HUDO TELESNO POŠKODBO"):
        item = (item[0], item[1] + 1, item[2])
    elif (row["KlasifikacijaNesrece"] == "S SMRTNIM IZIDOM"):
        item = (item[0], item[1], item[2] + 1)
    amounts_dict[key] = item
    return amounts_dict


def accidents_by_alcohol_amount():
    amounts_dict = dict()
    i = 0
    for row in data:
        a_alc = float(row["VrednostStrokovnegaPregleda"])
        if (a_alc == 0):
            a_alc = float(row["VrednostAlkotesta"]) * 2.083
        if a_alc == 0:
            a_alc_class = 0
        elif (a_alc <= 0.5):
             a_alc_class = 0.5
        elif (a_alc <= 1):
            a_alc_class = 1
        elif (a_alc <= 1.5):
            a_alc_class = 1.5
        elif (a_alc <= 2):
            a_alc_class = 2
        elif (a_alc <= 2.5):
            a_alc_class = 2.5
        else:
            a_alc_class = 3
        if amounts_dict.get(a_alc_class) is not None:
            amounts_dict = qulify_accident(amounts_dict, a_alc_class, row)
        else:
            amounts_dict[a_alc_class] = (0, 0, 0)
            amounts_dict = qulify_accident(amounts_dict, a_alc_class, row)
    print(i)
    return amounts_dict

alcohol_to_type = accidents_by_alcohol_amount()
# Out:
# 0

# %%
#Geolocational graph

BBox = (df_geo[1].min(), df_geo[1].max(), df_geo[0].min(), df_geo[0].max())
slo_map = plt.imread('../data/map.png')

fig, ax = plt.subplots(figsize=(9, 8))
_ = ax.scatter(df_geo[1], df_geo[0], zorder=1, alpha=0.2, c='b', s=1)

ax.set_title('Lokacije nesreč v Sloveniji')
ax.set_xlim(BBox[0], BBox[1])
ax.set_ylim(BBox[2], BBox[3])
_ = ax.imshow(slo_map, zorder=0, extent=BBox, aspect='equal')

# %% [markdown]
# Ali obstaja povezava med vsebnostjo alkohola in resnostjo nesreč ?

# %%
accidents_alc = (0,0,0)
accidents_sober = None
for alc_amount in alcohol_to_type.keys():
    if (alc_amount > 0):
        x = alcohol_to_type[alc_amount]
        accidents_alc = (accidents_alc[0] + x[0], accidents_alc[1] + x[1], accidents_alc[2] + x[2])
    else:
        accidents_sober = alcohol_to_type[alc_amount]

print(f"Smrt, trezen: {round(accidents_sober[2] / accidents_sober[0] * 100, 2)}%")
print(f"Smrt, alkoholiziran: {round(accidents_alc[2] / accidents_alc[0] * 100, 2)}%")

print(f"Težje poškodbe ali smrt, trezen: {round((accidents_sober[1] + accidents_sober[2])/ accidents_sober[0] * 100, 2)}%")
print(f"Težje poškodbe ali smrt, alkoholiziran: {round((accidents_alc[1] + accidents_alc[2]) / accidents_alc[0] * 100, 2)}%")
# Out:
# Smrt, trezen: 0.63%
# Smrt, alkoholiziran: 2.24%
# Težje poškodbe ali smrt, trezen: 4.63%
# Težje poškodbe ali smrt, alkoholiziran: 11.07%

# %%
#Povezanost med vsebnostjo alkohola in nesrečami s težkimi poškodbami in smrtmi
alcohol_amounts = sorted(alcohol_to_type.keys())
ratios_injury_death = []
ratios_death = []
for key in alcohol_amounts:
    item = alcohol_to_type[key]
    try:
        ratios_injury_death.append((item[1] + item[2]) / item[0] * 100)
        ratios_death.append((item[2]) / item[0] * 100)
    except ZeroDivisionError:
        pass

fig, ax = plt.subplots(1, 2, figsize=(9, 3))
ax[0].plot(alcohol_amounts, ratios_injury_death ,c='r')

ax[1].plot(alcohol_amounts, ratios_death ,c='r')

ax[0].set_title('Vsebnost alkohola in procent nesreč,\n pri katerih je prišlo do težjih poškodb ali do smrti')
ax[1].set_title("Vsebnost alkohola in procent nesreč,\n pri katerih je prišlo do smrti")
ax[0].set_ylabel("Procent nesreč")
ax[0].set_xlabel("Promil alkohola v krvi")
ax[1].set_ylabel("Procent nesreč")
ax[1].set_xlabel("Promil alkohola v krvi")
# Out:
# Text(0.5, 0, 'Promil alkohola v krvi')

# %%
count_above_proposed = 0
count_above_current = 0
count_above_max = 0
count_alcoholized = 0
for row in data:
    amount_of_alcohol = float(row["VrednostStrokovnegaPregleda"])
    if (amount_of_alcohol == 0):
        amount_of_alcohol = float(row["VrednostAlkotesta"]) * 2.083
    if (amount_of_alcohol > 0):
        count_alcoholized += 1
    if amount_of_alcohol > 0.2:
        count_above_proposed += 1
    if amount_of_alcohol > 0.5:
        count_above_current += 1
    if amount_of_alcohol > 1.1:
        count_above_max += 1
between_current_and_proposed = count_above_proposed-count_above_current
print(
    f"nad 0.2: {count_above_proposed}, \n"
    f"nad 0.5: {count_above_current}, \n"
    f"nad 1.1: {count_above_max} ({round(count_above_max / count_alcoholized * 100, 2)}%), \n"
    f"Število alkoholiziranih: {count_alcoholized}, \n"
    f"število nesreč: {len(data)}")
print(f"Med 0.2 in 0.5: {between_current_and_proposed} "
      f"({round(between_current_and_proposed / count_alcoholized * 100, 2)}%)")
# Out:
# nad 0.2: 19684,
# nad 0.5: 17054,
# nad 1.1: 12094 (53.61%),
# Število alkoholiziranih: 22558,
# število nesreč: 342963
# Med 0.2 in 0.5: 2630 (11.66%)

# %%
#nivoAlkohola = []
#stanjeNesrece = []
#for row in data:
#    alc = float(row['VrednostStrokovnegaPregleda'])
#    if(alc == 0):
#        alc = float(row['VrednostAlkotesta']) * 2.083
#     
#    if(alc > 0):
#        nivoAlkohola.append(alc)
#        
#        klasifikacija = row['KlasifikacijaNesrece']
#        if(klasifikacija == 'Z MATERIALNO ŠKODO'):
#            stanjeNesrece.append(1)
#        elif(klasifikacija == 'Z LAŽJO POŠKODBO'):
#            stanjeNesrece.append(2)
#        elif(klasifikacija == 'S HUDO TELESNO POŠKODBO'):
#            stanjeNesrece.append(3)
#        elif(klasifikacija == 'S SMTRNIM IZIDOM'):
#            stanjeNesrece.append(4)
#        else:
#            stanjeNesrece.append(0)

# %%
#def pearson(x y):
#    return np.mean(((x - np.mean(x))*(y-np.mean(y)))/(np.std(x)*np.std(y)))

# %%
#pearson(nivoAlkohola stanjeNesrece)
#stanjeNesrece

# %%
tipNesrece = {}
for row in data:
    alc = float(row['VrednostStrokovnegaPregleda'])
    if(alc == 0):
        alc = float(row['VrednostAlkotesta']) * 2.083
            
    if(alc > 0):
        if(row['TipNesrece'] in tipNesrece):
            tipNesrece[row['TipNesrece']] = tipNesrece[row['TipNesrece']] + 1
        else:
            tipNesrece[row['TipNesrece']] = 1
    
vsotaNesrec = 0
for row in tipNesrece.items():
    vsotaNesrec = vsotaNesrec + row[1]
print(
    f"Število trčenj v objekt: {tipNesrece['TRČENJE V OBJEKT']}, \n"
    f"Število čelnih trčenj: {tipNesrece['ČELNO TRČENJE']}, \n"
    f"Število naletnih trčenj: {tipNesrece['NALETNO TRČENJE']}, \n"
    f"Število oplaženj: {tipNesrece['OPLAŽENJE']}, \n" 
    f"Število prevrnitev vozil: {tipNesrece['PREVRNITEV VOZILA']}, \n" 
    f"Število trčenj v stoječe / parkirano vozilo: {tipNesrece['TRČENJE V STOJEČE / PARKIRANO VOZILO']}, \n" 
    f"Število povoženj pešecev: {tipNesrece['POVOŽENJE PEŠCA']}, \n" 
    f"Število povoženj živali: {tipNesrece['POVOŽENJE ŽIVALI']}, \n" 
    f"Število ostalih vrst trčenj: {tipNesrece['OSTALO']}, \n" 
    f"Število nesreč v vinjenem stanju: {vsotaNesrec}")
# Out:
# Število trčenj v objekt: 4086,
# Število čelnih trčenj: 2836,
# Število naletnih trčenj: 2159,
# Število oplaženj: 2206,
# Število prevrnitev vozil: 2533,
# Število trčenj v stoječe / parkirano vozilo: 2257,
# Število povoženj pešecev: 573,
# Število povoženj živali: 109,
# Število ostalih vrst trčenj: 1972,
# Število nesreč v vinjenem stanju: 22558

# %%
tipNesrece = dict(sorted(tipNesrece.items(), key=lambda item: item[1], reverse=True))
vrstaNesrec = [row for row in tipNesrece.keys()]
stNesrec = [tipNesrece[row] for row in vrstaNesrec]
    
fig = plt.figure(figsize = (25, 10))
plt.bar(vrstaNesrec, stNesrec, width=0.5)
     
plt.ylabel('Število nesreč posameznega tipa')
plt.title('Najbolj pogosti tipi nasreč ki se zgodijo v stanju vinjenosti')
plt.show()

# %%
starostneSkupine = {
    '10-14': 0,
    '15-19': 0,
    '20-24': 0,
    '25-29': 0,
    '30-34': 0,
    '35-39': 0,
    '40-44': 0,
    '45-49': 0,
    '50-54': 0,
    '55-59': 0,
    '60-64': 0,
    '65-69': 0,
    '70-74': 0,
    '75-79': 0,
    '80-84': 0,
    '85-89': 0,
    '90+': 0
}

for row in data:
    alc = float(row['VrednostStrokovnegaPregleda'])
    if(alc == 0):
        alc = float(row['VrednostAlkotesta']) * 2.083
            
    if(alc > 0):
        if(10 <= int(row['Starost']) < 15):
            starostneSkupine['10-14'] = starostneSkupine['10-14'] + 1
                
        elif(15 <= int(row['Starost']) < 20):
            starostneSkupine['15-19'] = starostneSkupine['15-19'] + 1
                
        elif(20 <= int(row['Starost']) < 25):
            starostneSkupine['20-24'] = starostneSkupine['20-24'] + 1
               
        elif(25 <= int(row['Starost']) < 30):
            starostneSkupine['25-29'] = starostneSkupine['25-29'] + 1
    
        elif(30 <= int(row['Starost']) <  35):
            starostneSkupine['30-34'] = starostneSkupine['30-34'] + 1
            
        elif(35 <= int(row['Starost']) <  40):
            starostneSkupine['35-39'] = starostneSkupine['35-39'] + 1
            
        elif(40 <= int(row['Starost']) <  45):
            starostneSkupine['40-44'] = starostneSkupine['40-44'] + 1
    
        elif(45 <= int(row['Starost']) < 50):
            starostneSkupine['45-49'] = starostneSkupine['45-49'] + 1
    
        elif(50 <= int(row['Starost']) < 55):
            starostneSkupine['50-54'] = starostneSkupine['50-54'] + 1
    
        elif(55 <= int(row['Starost']) < 60):
            starostneSkupine['55-59'] = starostneSkupine['55-59'] + 1
    
        elif(60 <= int(row['Starost']) <  65):
            starostneSkupine['60-64'] = starostneSkupine['60-64'] + 1
    
        elif(65 <= int(row['Starost']) < 70):
            starostneSkupine['65-69'] = starostneSkupine['65-69'] + 1
    
        elif(70 <= int(row['Starost']) < 75):
            starostneSkupine['70-74'] = starostneSkupine['70-74'] + 1
    
        elif(75 <= int(row['Starost']) < 80):
            starostneSkupine['75-79'] = starostneSkupine['75-79'] + 1
    
        elif(80 <= int(row['Starost']) <  85):
            starostneSkupine['80-84'] = starostneSkupine['80-84'] + 1
    
        elif(85 <= int(row['Starost']) < 90):
            starostneSkupine['85-89'] = starostneSkupine['85-89'] + 1
    
        else:
            starostneSkupine['90+'] = starostneSkupine['90+'] + 1

# %%
starostneSkupine
# Out:
# {'10-14': 6,
#  '15-19': 714,
#  '20-24': 2603,
#  '25-29': 2653,
#  '30-34': 2490,
#  '35-39': 2368,
#  '40-44': 2188,
#  '45-49': 2126,
#  '50-54': 2008,
#  '55-59': 1821,
#  '60-64': 1436,
#  '65-69': 999,
#  '70-74': 607,
#  '75-79': 370,
#  '80-84': 129,
#  '85-89': 35,
#  '90+': 5}

# %%
starostniRazmak = [row for row in starostneSkupine.keys()]
steviloPojavitev = [starostneSkupine[row] for row in starostniRazmak]

fig = plt.figure(figsize = (25, 10))
plt.bar(starostniRazmak, steviloPojavitev, width=0.5)

plt.ylabel("Število nesreč")
plt.title("Število nesreč, v stanju vinjenosti za vse starostne skupine")
plt.show()

# %% [markdown]
# Ali je alkohol glavni vzrok za hujše nesreče ?

# %%
#Razrede pretvorimo v številke

row = data[0]
x = row.keys()
for a in x:
    print(a)

# for row in data:
#     keys = row.keys()
#     for key in keys:
#         if (key == "UraPN"):
#             continue
#         elif (key == "SifraOdsekaUlice" or key == "GeoKoordinataX"or key == "GeoKoordinataY" or
#                 key == "ZaporednaStevilkaOsebeVPN" or key == "Starost" or key == "VozniskiStazVLetih" or
#                 key == "VozniskiStazVMesecih" or key == "VrednostAlkotesta" or key == "VrednostStrokovnegaPregleda")
# Out:
# ﻿ZaporednaStevilkaPN
# KlasifikacijaNesrece
# UpravnaEnotaStoritve
# DatumPN
# UraPN
# VNaselju
# Lokacija
# VrstaCesteNaselja
# SifraCesteNaselja
# TekstCesteNaselja
# SifraOdsekaUlice
# TekstOdsekaUlice
# StacionazaDogodka
# OpisKraja
# VzrokNesrece
# TipNesrece
# VremenskeOkoliscine
# StanjePrometa
# StanjeVozisca
# VrstaVozisca
# GeoKoordinataX
# GeoKoordinataY
# ZaporednaStevilkaOsebeVPN
# Povzrocitelj
# Starost
# Spol
# UEStalnegaPrebivalisca
# Drzavljanstvo
# PoskodbaUdelezenca
# VrstaUdelezenca
# UporabaVarnostnegaPasu
# VozniskiStazVLetih
# VozniskiStazVMesecih
# VrednostAlkotesta
# VrednostStrokovnegaPregleda

# %%
def normalise(x, min_value, max_value, scale):
    return math.floor(((x-min_value) / (max_value-min_value)) * scale)

def get_traffic_amount(color):
    if color in [(0, 0, 0), (255, 255, 255), (252, 252, 254), (252, 252, 250), (248, 248, 247)]:
        return "0"
    elif color in [(242, 98, 96), (222, 137, 152)]:
        return "nad 20000"
    elif color in [(163, 194, 226), (104, 155, 217), (22, 118, 237)]:
        return "nad 10000"
    elif color in [(208, 187, 198), (170, 132, 164)]:
        return "nad 5000"
    elif color in [(172, 217, 144), (141, 219, 82)]:
        return "nad 1000"
    elif color in [(230, 230, 219), (229, 225, 163), (255, 255, 1)]:
        return "do 1000"
    else:
        return "null"

#df_geo[0] is x
#df_geo[1] is y

BBox = (df_geo[0].min(), df_geo[0].max(), df_geo[1].min(), df_geo[1].max())
def rate_bounds(img, bounds: tuple):
    count_resolved = 0
    img_crop = img.crop(bounds)
    for row in data:
        latitude = float(row["GeoKoordinataX"])
        longitude = float(row["GeoKoordinataY"])
        #if (longitude == 0.0 or latitude == 0.0):
        #    continue
        pixel_x = normalise(latitude, BBox[0], BBox[1], img_crop.size[0])
        pixel_y = normalise(longitude, BBox[2], BBox[3], img_crop.size[1])
        try:
            traffic_amount = get_traffic_amount(img_crop.getpixel((pixel_x, pixel_y)))
            if traffic_amount != "null" and traffic_amount != "0":
                count_resolved += 1
        except Exception as e:
           pass
    return count_resolved

def create_bounds(original = False):
    map = Image.open("../data/razporeditev prometa.png")
    if original:
        left = 0
        top = 0
        right = map.size[0]
        bottom = map.size[1]
    else:
        left = random.randint(1, 10)
        top = random.randint(1, 10)
        right = map.size[0] - random.randint(1, 10)
        bottom = map.size[1] - random.randint(1, 10)
    bounds = (left, top, right, bottom)
    rating = rate_bounds(map, bounds)
    return bounds, rating
# The crop on the image is not right, we try random crops and see how well the accidents cover the roads
# bounds_dict = {}
# bounds, rating = create_bounds(original=True)
# print("With no crop: " + str(rating))
# for i in range(1000):
#     bounds, rating = create_bounds()
#     bounds_dict[rating] = bounds
# for key in sorted(bounds_dict):
#     print("%s: %s" % (key, bounds_dict[key]))

"""
With no crop: 228703
200368: (10, 10, 914, 610)
200677: (3, 10, 913, 610)
202363: (7, 10, 912, 610)
203681: (1, 10, 911, 610)
.
.
.
251797: (2, 3, 905, 607)
251993: (3, 2, 905, 608)
252651: (3, 3, 905, 607)
257237: (4, 3, 905, 606)
258134: (6, 2, 905, 606)
265361: (6, 1, 905, 607)
267207: (4, 1, 905, 608)
"""
# Out:
# '\nWith no crop: 228703\n200368: (10, 10, 914, 610)\n200677: (3, 10, 913, 610)\n202363: (7, 10, 912, 610)\n203681: (1, 10, 911, 610)\n.\n.\n.\n251797: (2, 3, 905, 607)\n251993: (3, 2, 905, 608)\n252651: (3, 3, 905, 607)\n257237: (4, 3, 905, 606)\n258134: (6, 2, 905, 606)\n265361: (6, 1, 905, 607)\n267207: (4, 1, 905, 608)\n'

# %%
# Finally adding the traffic amount column
map = Image.open("../data/razporeditev prometa.png")
img_crop = map.crop((4, 1, 905, 608))
for row in data:
    latitude = float(row["GeoKoordinataX"])
    longitude = float(row["GeoKoordinataY"])
    #if (longitude == 0.0 or latitude == 0.0):
    #    continue
    pixel_x = normalise(latitude, BBox[0], BBox[1], img_crop.size[0])
    pixel_y = normalise(longitude, BBox[2], BBox[3], img_crop.size[1])
    try:
        traffic_amount = get_traffic_amount(img_crop.getpixel((pixel_x, pixel_y)))
        row["Gostota prometa"] = traffic_amount
    except Exception as e:
       row["Gostota prometa"] = "0"

# %%
drunk_drivers = [[], []]
for row in data:
    alc = float(row['VrednostStrokovnegaPregleda'])
    if(alc == 0):
        alc = float(row['VrednostAlkotesta']) * 2.083
            
    if(alc > 0):
        if (row["KlasifikacijaNesrece"] == "S HUDO TELESNO POŠKODBO"):
            drunk_drivers[0].append(row)
        elif (row["KlasifikacijaNesrece"] == "S SMRTNIM IZIDOM"):
            drunk_drivers[1].append(row)

# 0, do 1000, nad 1000, nad 5000, nad 10.000, nad 20.000
# S hudo telesno poškodbo
major_injury = {}
print(len(drunk_drivers[0]))
for row in drunk_drivers[0]:
    if(row['Gostota prometa'] in major_injury):
        major_injury[row['Gostota prometa']] += 1
    else:
        major_injury[row['Gostota prometa']] = 0
major_injury
# Out:
# 1992
# {'\ufeffZaporednaStevilkaPN': '5', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'TRŽIČ', 'DatumPN': '1.01.2011', 'UraPN': 'feb.30', 'VNaselju': 'NE', 'Lokacija': 'CESTA', 'VrstaCesteNaselja': 'GLAVNA CESTA II. REDA', 'SifraCesteNaselja': '101', 'TekstCesteNaselja': 'LJUBELJ-BISTRICA-PODTABOR', 'SifraOdsekaUlice': '232', 'TekstOdsekaUlice': 'LJUBELJ-BISTRICA TRŽIČ', 'StacionazaDogodka': '3500', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRILAGOJENA HITROST', 'TipNesrece': 'TRČENJE V OBJEKT', 'VremenskeOkoliscine': 'JASNO', 'StanjePrometa': 'REDEK', 'StanjeVozisca': 'MOKRO', 'VrstaVozisca': 'HRAPAV  ASFALT / BETON', 'GeoKoordinataX': '142287', 'GeoKoordinataY': '444218', 'ZaporednaStevilkaOsebeVPN': '5001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '26', 'Spol': 'ŽENSKI', 'UEStalnegaPrebivalisca': 'KRANJ', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'DA', 'VozniskiStazVLetih': '4', 'VozniskiStazVMesecih': '10', 'VrednostAlkotesta': '0.28', 'VrednostStrokovnegaPregleda': '0', 'Gostota prometa': 'do 1000'}
# {'\ufeffZaporednaStevilkaPN': '8', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'LJUBLJANA', 'DatumPN': '1.01.2011', 'UraPN': '18.15', 'VNaselju': 'DA', 'Lokacija': 'NASELJE', 'VrstaCesteNaselja': 'NASELJE Z ULIČNIM SISTEMOM', 'SifraCesteNaselja': '25001', 'TekstCesteNaselja': 'LJUBLJANA', 'SifraOdsekaUlice': '25205', 'TekstOdsekaUlice': 'ZALOŠKA CESTA', 'StacionazaDogodka': '87', 'OpisKraja': 'KRIŽIŠČE', 'VzrokNesrece': 'NEUPOŠTEVANJE PRAVIL O PREDNOSTI', 'TipNesrece': 'ČELNO TRČENJE', 'VremenskeOkoliscine': 'OBLAČNO', 'StanjePrometa': 'NORMALEN', 'StanjeVozisca': 'MOKRO', 'VrstaVozisca': 'HRAPAV  ASFALT / BETON', 'GeoKoordinataX': '101426', 'GeoKoordinataY': '464879', 'ZaporednaStevilkaOsebeVPN': '8001', 'Povzrocitelj': 'UDELEŽENEC', 'Starost': '59', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'LJUBLJANA', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'DA', 'VozniskiStazVLetih': '14', 'VozniskiStazVMesecih': '8', 'VrednostAlkotesta': '0.21', 'VrednostStrokovnegaPregleda': '0', 'Gostota prometa': 'nad 5000'}
# {'\ufeffZaporednaStevilkaPN': '86', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'MARIBOR', 'DatumPN': '3.01.2011', 'UraPN': '18.00', 'VNaselju': 'DA', 'Lokacija': 'NASELJE', 'VrstaCesteNaselja': 'NASELJE BREZ ULIČNEGA SISTEMA', 'SifraCesteNaselja': '64082', 'TekstCesteNaselja': 'ZGORNJI DUPLEK', 'SifraOdsekaUlice': '0', 'TekstOdsekaUlice': 'NI ODSEKOV', 'StacionazaDogodka': '11', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRILAGOJENA HITROST', 'TipNesrece': 'TRČENJE V OBJEKT', 'VremenskeOkoliscine': 'JASNO', 'StanjePrometa': 'NORMALEN', 'StanjeVozisca': 'SUHO', 'VrstaVozisca': 'HRAPAV  ASFALT / BETON', 'GeoKoordinataX': '152208', 'GeoKoordinataY': '555603', 'ZaporednaStevilkaOsebeVPN': '86001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '39', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'PTUJ', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'DA', 'VozniskiStazVLetih': '21', 'VozniskiStazVMesecih': '4', 'VrednostAlkotesta': '0.63', 'VrednostStrokovnegaPregleda': '0', 'Gostota prometa': 'nad 10000'}
# {'\ufeffZaporednaStevilkaPN': '244', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'DOMŽALE', 'DatumPN': '7.01.2011', 'UraPN': '15.30', 'VNaselju': 'DA', 'Lokacija': 'NASELJE', 'VrstaCesteNaselja': 'NASELJE BREZ ULIČNEGA SISTEMA', 'SifraCesteNaselja': '6147', 'TekstCesteNaselja': 'ZAGORICA PRI ROVAH', 'SifraOdsekaUlice': '0', 'TekstOdsekaUlice': 'NI ODSEKOV', 'StacionazaDogodka': '1', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRILAGOJENA HITROST', 'TipNesrece': 'PREVRNITEV VOZILA', 'VremenskeOkoliscine': 'OBLAČNO', 'StanjePrometa': 'REDEK', 'StanjeVozisca': 'MOKRO', 'VrstaVozisca': 'ZGLAJEN ASFALT / BETON', 'GeoKoordinataX': '115025', 'GeoKoordinataY': '473551', 'ZaporednaStevilkaOsebeVPN': '244001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '60', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'DOMŽALE', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'KOLESAR', 'UporabaVarnostnegaPasu': 'NE', 'VozniskiStazVLetih': '0', 'VozniskiStazVMesecih': '0', 'VrednostAlkotesta': '0', 'VrednostStrokovnegaPregleda': '2.59', 'Gostota prometa': '0'}
# {'\ufeffZaporednaStevilkaPN': '287', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'ŠMARJE PRI JELŠAH', 'DatumPN': '8.01.2011', 'UraPN': '17.35', 'VNaselju': 'NE', 'Lokacija': 'CESTA', 'VrstaCesteNaselja': 'GLAVNA CESTA II. REDA', 'SifraCesteNaselja': '107', 'TekstCesteNaselja': 'CELJE-ŠENTJ PRI C-DOBOVEC', 'SifraOdsekaUlice': '1276', 'TekstOdsekaUlice': 'PODPLAT-ROGATEC', 'StacionazaDogodka': '8844', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEUPOŠTEVANJE PRAVIL O PREDNOSTI', 'TipNesrece': 'ČELNO TRČENJE', 'VremenskeOkoliscine': 'JASNO', 'StanjePrometa': 'NORMALEN', 'StanjeVozisca': 'SUHO', 'VrstaVozisca': 'ZGLAJEN ASFALT / BETON', 'GeoKoordinataX': '122118', 'GeoKoordinataY': '551810', 'ZaporednaStevilkaOsebeVPN': '287003', 'Povzrocitelj': 'UDELEŽENEC', 'Starost': '51', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'ŠMARJE PRI JELŠAH', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'LAŽJA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'DA', 'VozniskiStazVLetih': '21', 'VozniskiStazVMesecih': '8', 'VrednostAlkotesta': '0.02', 'VrednostStrokovnegaPregleda': '0', 'Gostota prometa': 'do 1000'}
# {'\ufeffZaporednaStevilkaPN': '321', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'PIRAN', 'DatumPN': '9.01.2011', 'UraPN': '23.00', 'VNaselju': 'DA', 'Lokacija': 'NASELJE', 'VrstaCesteNaselja': 'NASELJE Z ULIČNIM SISTEMOM', 'SifraCesteNaselja': '40007', 'TekstCesteNaselja': 'PORTOROŽ', 'SifraOdsekaUlice': '8', 'TekstOdsekaUlice': 'KOPRSKA CESTA', 'StacionazaDogodka': '11', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRAVILNA STRAN / SMER VOŽNJE', 'TipNesrece': 'TRČENJE V OBJEKT', 'VremenskeOkoliscine': 'OBLAČNO', 'StanjePrometa': 'REDEK', 'StanjeVozisca': 'MOKRO', 'VrstaVozisca': 'HRAPAV  ASFALT / BETON', 'GeoKoordinataX': '42402', 'GeoKoordinataY': '391043', 'ZaporednaStevilkaOsebeVPN': '321001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '23', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'TUJINA', 'Drzavljanstvo': 'HRVAŠKA', 'PoskodbaUdelezenca': 'LAŽJA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'NE', 'VozniskiStazVLetih': '4', 'VozniskiStazVMesecih': '11', 'VrednostAlkotesta': '0.58', 'VrednostStrokovnegaPregleda': '1.01', 'Gostota prometa': 'nad 10000'}
# {'\ufeffZaporednaStevilkaPN': '373', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'NOVO MESTO', 'DatumPN': '6.01.2011', 'UraPN': '00.30', 'VNaselju': 'DA', 'Lokacija': 'NASELJE', 'VrstaCesteNaselja': 'NASELJE BREZ ULIČNEGA SISTEMA', 'SifraCesteNaselja': '38002', 'TekstCesteNaselja': 'BELA CERKEV', 'SifraOdsekaUlice': '0', 'TekstOdsekaUlice': 'NI ODSEKOV', 'StacionazaDogodka': '18', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRILAGOJENA HITROST', 'TipNesrece': 'TRČENJE V OBJEKT', 'VremenskeOkoliscine': 'JASNO', 'StanjePrometa': 'REDEK', 'StanjeVozisca': 'SUHO', 'VrstaVozisca': 'HRAPAV  ASFALT / BETON', 'GeoKoordinataX': '80387', 'GeoKoordinataY': '521778', 'ZaporednaStevilkaOsebeVPN': '373001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '41', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'NOVO MESTO', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'DA', 'VozniskiStazVLetih': '19', 'VozniskiStazVMesecih': '9', 'VrednostAlkotesta': '0.7', 'VrednostStrokovnegaPregleda': '0', 'Gostota prometa': 'nad 1000'}
# {'\ufeffZaporednaStevilkaPN': '400', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'ŠKOFJA LOKA', 'DatumPN': '15.01.2011', 'UraPN': 'maj.20', 'VNaselju': 'DA', 'Lokacija': 'NASELJE', 'VrstaCesteNaselja': 'NASELJE Z ULIČNIM SISTEMOM', 'SifraCesteNaselja': '53180', 'TekstCesteNaselja': 'ŽELEZNIKI-ŽELEZNIKI', 'SifraOdsekaUlice': '10', 'TekstOdsekaUlice': 'DAŠNICA', 'StacionazaDogodka': '78', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRILAGOJENA HITROST', 'TipNesrece': 'TRČENJE V STOJEČE / PARKIRANO VOZILO', 'VremenskeOkoliscine': 'JASNO', 'StanjePrometa': 'REDEK', 'StanjeVozisca': 'MOKRO', 'VrstaVozisca': 'HRAPAV  ASFALT / BETON', 'GeoKoordinataX': '120883', 'GeoKoordinataY': '435545', 'ZaporednaStevilkaOsebeVPN': '400003', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '21', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'ŠKOFJA LOKA', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'DA', 'VozniskiStazVLetih': '3', 'VozniskiStazVMesecih': '4', 'VrednostAlkotesta': '0', 'VrednostStrokovnegaPregleda': '1.53', 'Gostota prometa': '0'}
# {'\ufeffZaporednaStevilkaPN': '455', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'RADOVLJICA', 'DatumPN': '16.01.2011', 'UraPN': '18.20', 'VNaselju': 'DA', 'Lokacija': 'NASELJE', 'VrstaCesteNaselja': 'NASELJE BREZ ULIČNEGA SISTEMA', 'SifraCesteNaselja': '44078', 'TekstCesteNaselja': 'SREDNJA VAS V BOHINJU', 'SifraOdsekaUlice': '0', 'TekstOdsekaUlice': 'NI ODSEKOV', 'StacionazaDogodka': '87', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRILAGOJENA HITROST', 'TipNesrece': 'POVOŽENJE PEŠCA', 'VremenskeOkoliscine': 'OBLAČNO', 'StanjePrometa': 'NORMALEN', 'StanjeVozisca': 'MOKRO', 'VrstaVozisca': 'ZGLAJEN ASFALT / BETON', 'GeoKoordinataX': '128498', 'GeoKoordinataY': '418150', 'ZaporednaStevilkaOsebeVPN': '455003', 'Povzrocitelj': 'UDELEŽENEC', 'Starost': '47', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'RADOVLJICA', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'BREZ POŠKODBE', 'VrstaUdelezenca': 'PEŠEC', 'UporabaVarnostnegaPasu': 'NEZNANO', 'VozniskiStazVLetih': '0', 'VozniskiStazVMesecih': '0', 'VrednostAlkotesta': '0.63', 'VrednostStrokovnegaPregleda': '0', 'Gostota prometa': 'nad 1000'}
# {'\ufeffZaporednaStevilkaPN': '475', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'TOLMIN', 'DatumPN': '14.01.2011', 'UraPN': '21.30', 'VNaselju': 'NE', 'Lokacija': 'CESTA', 'VrstaCesteNaselja': 'GLAVNA CESTA II. REDA', 'SifraCesteNaselja': '102', 'TekstCesteNaselja': 'ROBIČ-IDRIJA-LOGATEC', 'SifraOdsekaUlice': '1031', 'TekstOdsekaUlice': 'ROBIČ-STARO SELO', 'StacionazaDogodka': '1500', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRAVILNA STRAN / SMER VOŽNJE', 'TipNesrece': 'TRČENJE V OBJEKT', 'VremenskeOkoliscine': 'MEGLA', 'StanjePrometa': 'NORMALEN', 'StanjeVozisca': 'SUHO', 'VrstaVozisca': 'ZGLAJEN ASFALT / BETON', 'GeoKoordinataX': '121636', 'GeoKoordinataY': '384754', 'ZaporednaStevilkaOsebeVPN': '475001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '24', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'TOLMIN', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'DA', 'VozniskiStazVLetih': '0', 'VozniskiStazVMesecih': '0', 'VrednostAlkotesta': '0.03', 'VrednostStrokovnegaPregleda': '0', 'Gostota prometa': 'do 1000'}
# {'\ufeffZaporednaStevilkaPN': '553', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'KAMNIK', 'DatumPN': '16.01.2011', 'UraPN': '16.18', 'VNaselju': 'DA', 'Lokacija': 'NASELJE', 'VrstaCesteNaselja': 'NASELJE Z ULIČNIM SISTEMOM', 'SifraCesteNaselja': '15024', 'TekstCesteNaselja': 'KAMNIK', 'SifraOdsekaUlice': '21', 'TekstOdsekaUlice': 'KRANJSKA CESTA', 'StacionazaDogodka': '4', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRAVILNOSTI PEŠCA', 'TipNesrece': 'POVOŽENJE PEŠCA', 'VremenskeOkoliscine': 'JASNO', 'StanjePrometa': 'NORMALEN', 'StanjeVozisca': 'SUHO', 'VrstaVozisca': 'HRAPAV  ASFALT / BETON', 'GeoKoordinataX': '119695', 'GeoKoordinataY': '469802', 'ZaporednaStevilkaOsebeVPN': '553001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '76', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'KAMNIK', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'PEŠEC', 'UporabaVarnostnegaPasu': 'NEZNANO', 'VozniskiStazVLetih': '0', 'VozniskiStazVMesecih': '0', 'VrednostAlkotesta': '0.11', 'VrednostStrokovnegaPregleda': '0', 'Gostota prometa': 'nad 10000'}
# {'\ufeffZaporednaStevilkaPN': '661', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'BREŽICE', 'DatumPN': '16.01.2011', 'UraPN': '22.13', 'VNaselju': 'DA', 'Lokacija': 'NASELJE', 'VrstaCesteNaselja': 'NASELJE BREZ ULIČNEGA SISTEMA', 'SifraCesteNaselja': '2095', 'TekstCesteNaselja': 'STOJANSKI VRH', 'SifraOdsekaUlice': '0', 'TekstOdsekaUlice': 'NI ODSEKOV', 'StacionazaDogodka': '1', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRILAGOJENA HITROST', 'TipNesrece': 'TRČENJE V OBJEKT', 'VremenskeOkoliscine': 'JASNO', 'StanjePrometa': 'REDEK', 'StanjeVozisca': 'SUHO', 'VrstaVozisca': 'ZGLAJEN ASFALT / BETON', 'GeoKoordinataX': '79995', 'GeoKoordinataY': '542284', 'ZaporednaStevilkaOsebeVPN': '661001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '27', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'BREŽICE', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'BREZ POŠKODBE', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'DA', 'VozniskiStazVLetih': '8', 'VozniskiStazVMesecih': '4', 'VrednostAlkotesta': '0.67', 'VrednostStrokovnegaPregleda': '1.52', 'Gostota prometa': '0'}
# {'\ufeffZaporednaStevilkaPN': '680', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'POSTOJNA', 'DatumPN': '23.01.2011', 'UraPN': '05.00', 'VNaselju': 'NE', 'Lokacija': 'CESTA', 'VrstaCesteNaselja': 'LOKALNA CESTA', 'SifraCesteNaselja': '41104', 'TekstCesteNaselja': '321310 G16-SMET-R2409', 'SifraOdsekaUlice': '0', 'TekstOdsekaUlice': 'NI ODSEKOV', 'StacionazaDogodka': '0', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRILAGOJENA HITROST', 'TipNesrece': 'PREVRNITEV VOZILA', 'VremenskeOkoliscine': 'OBLAČNO', 'StanjePrometa': 'REDEK', 'StanjeVozisca': 'SUHO', 'VrstaVozisca': 'MAKADAM', 'GeoKoordinataX': '0', 'GeoKoordinataY': '0', 'ZaporednaStevilkaOsebeVPN': '680003', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '28', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'POSTOJNA', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'NE', 'VozniskiStazVLetih': '2', 'VozniskiStazVMesecih': '5', 'VrednostAlkotesta': '0.63', 'VrednostStrokovnegaPregleda': '1.17', 'Gostota prometa': '0'}
# {'\ufeffZaporednaStevilkaPN': '712', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'MARIBOR', 'DatumPN': '1.01.2011', 'UraPN': 'feb.20', 'VNaselju': 'DA', 'Lokacija': 'NASELJE', 'VrstaCesteNaselja': 'NASELJE Z ULIČNIM SISTEMOM', 'SifraCesteNaselja': '64033', 'TekstCesteNaselja': 'MARIBOR', 'SifraOdsekaUlice': '254', 'TekstOdsekaUlice': 'LIMBUŠKA CESTA', 'StacionazaDogodka': '180', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRILAGOJENA HITROST', 'TipNesrece': 'ČELNO TRČENJE', 'VremenskeOkoliscine': 'OBLAČNO', 'StanjePrometa': 'NORMALEN', 'StanjeVozisca': 'SUHO', 'VrstaVozisca': 'HRAPAV  ASFALT / BETON', 'GeoKoordinataX': '157137', 'GeoKoordinataY': '546735', 'ZaporednaStevilkaOsebeVPN': '712001', 'Povzrocitelj': 'UDELEŽENEC', 'Starost': '31', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'RUŠE', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'LAŽJA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK TOVORNEGA VOZILA', 'UporabaVarnostnegaPasu': 'DA', 'VozniskiStazVLetih': '10', 'VozniskiStazVMesecih': '7', 'VrednostAlkotesta': '0.04', 'VrednostStrokovnegaPregleda': '0', 'Gostota prometa': 'do 1000'}
# {'\ufeffZaporednaStevilkaPN': '712', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'MARIBOR', 'DatumPN': '1.01.2011', 'UraPN': 'feb.20', 'VNaselju': 'DA', 'Lokacija': 'NASELJE', 'VrstaCesteNaselja': 'NASELJE Z ULIČNIM SISTEMOM', 'SifraCesteNaselja': '64033', 'TekstCesteNaselja': 'MARIBOR', 'SifraOdsekaUlice': '254', 'TekstOdsekaUlice': 'LIMBUŠKA CESTA', 'StacionazaDogodka': '180', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRILAGOJENA HITROST', 'TipNesrece': 'ČELNO TRČENJE', 'VremenskeOkoliscine': 'OBLAČNO', 'StanjePrometa': 'NORMALEN', 'StanjeVozisca': 'SUHO', 'VrstaVozisca': 'HRAPAV  ASFALT / BETON', 'GeoKoordinataX': '157137', 'GeoKoordinataY': '546735', 'ZaporednaStevilkaOsebeVPN': '712002', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '23', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'MARIBOR', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'DA', 'VozniskiStazVLetih': '4', 'VozniskiStazVMesecih': '9', 'VrednostAlkotesta': '0.68', 'VrednostStrokovnegaPregleda': '1.45', 'Gostota prometa': 'do 1000'}
# {'\ufeffZaporednaStevilkaPN': '712', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'MARIBOR', 'DatumPN': '1.01.2011', 'UraPN': 'feb.20', 'VNaselju': 'DA', 'Lokacija': 'NASELJE', 'VrstaCesteNaselja': 'NASELJE Z ULIČNIM SISTEMOM', 'SifraCesteNaselja': '64033', 'TekstCesteNaselja': 'MARIBOR', 'SifraOdsekaUlice': '254', 'TekstOdsekaUlice': 'LIMBUŠKA CESTA', 'StacionazaDogodka': '180', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRILAGOJENA HITROST', 'TipNesrece': 'ČELNO TRČENJE', 'VremenskeOkoliscine': 'OBLAČNO', 'StanjePrometa': 'NORMALEN', 'StanjeVozisca': 'SUHO', 'VrstaVozisca': 'HRAPAV  ASFALT / BETON', 'GeoKoordinataX': '157137', 'GeoKoordinataY': '546735', 'ZaporednaStevilkaOsebeVPN': '712004', 'Povzrocitelj': 'UDELEŽENEC', 'Starost': '20', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'MARIBOR', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'LAŽJA TELESNA POŠKODBA', 'VrstaUdelezenca': 'POTNIK', 'UporabaVarnostnegaPasu': 'DA', 'VozniskiStazVLetih': '0', 'VozniskiStazVMesecih': '0', 'VrednostAlkotesta': '0.43', 'VrednostStrokovnegaPregleda': '0', 'Gostota prometa': 'do 1000'}
# {'\ufeffZaporednaStevilkaPN': '869', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'LJUBLJANA', 'DatumPN': '23.01.2011', 'UraPN': 'maj.45', 'VNaselju': 'NE', 'Lokacija': 'CESTA', 'VrstaCesteNaselja': 'AVTOCESTA', 'SifraCesteNaselja': '000A1', 'TekstCesteNaselja': 'ŠENTILJ-MB-CE-LJ-PO-SRMIN', 'SifraOdsekaUlice': '650', 'TekstOdsekaUlice': 'LJ LITIJSKA-MALENCE', 'StacionazaDogodka': '2500', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRILAGOJENA HITROST', 'TipNesrece': 'TRČENJE V OBJEKT', 'VremenskeOkoliscine': 'JASNO', 'StanjePrometa': 'NORMALEN', 'StanjeVozisca': 'SUHO', 'VrstaVozisca': 'HRAPAV  ASFALT / BETON', 'GeoKoordinataX': '97737', 'GeoKoordinataY': '466685', 'ZaporednaStevilkaOsebeVPN': '869001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '37', 'Spol': 'ŽENSKI', 'UEStalnegaPrebivalisca': 'DOMŽALE', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'NE', 'VozniskiStazVLetih': '8', 'VozniskiStazVMesecih': '5', 'VrednostAlkotesta': '0', 'VrednostStrokovnegaPregleda': '0.72', 'Gostota prometa': 'nad 20000'}
# {'\ufeffZaporednaStevilkaPN': '1234', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'TOLMIN', 'DatumPN': '2.02.2011', 'UraPN': '16.40', 'VNaselju': 'DA', 'Lokacija': 'NASELJE', 'VrstaCesteNaselja': 'NASELJE BREZ ULIČNEGA SISTEMA', 'SifraCesteNaselja': '55045', 'TekstCesteNaselja': 'KRN', 'SifraOdsekaUlice': '0', 'TekstOdsekaUlice': 'NI ODSEKOV', 'StacionazaDogodka': '15', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'OSTALO', 'TipNesrece': 'PREVRNITEV VOZILA', 'VremenskeOkoliscine': 'JASNO', 'StanjePrometa': 'REDEK', 'StanjeVozisca': 'SUHO', 'VrstaVozisca': 'HRAPAV  ASFALT / BETON', 'GeoKoordinataX': '122217', 'GeoKoordinataY': '397962', 'ZaporednaStevilkaOsebeVPN': '1234001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '22', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'TOLMIN', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK TRAKTORJA', 'UporabaVarnostnegaPasu': 'DA', 'VozniskiStazVLetih': '0', 'VozniskiStazVMesecih': '0', 'VrednostAlkotesta': '0.62', 'VrednostStrokovnegaPregleda': '0', 'Gostota prometa': '0'}
# {'\ufeffZaporednaStevilkaPN': '1315', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'ORMOŽ', 'DatumPN': '5.02.2011', 'UraPN': 'feb.55', 'VNaselju': 'NE', 'Lokacija': 'CESTA', 'VrstaCesteNaselja': 'GLAVNA CESTA', 'SifraCesteNaselja': '2', 'TekstCesteNaselja': 'SLOV.BISTRICA-SRED. OB DR', 'SifraOdsekaUlice': '250', 'TekstOdsekaUlice': 'SPUHLJA-ORMOŽ', 'StacionazaDogodka': '17000', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRILAGOJENA HITROST', 'TipNesrece': 'PREVRNITEV VOZILA', 'VremenskeOkoliscine': 'JASNO', 'StanjePrometa': 'REDEK', 'StanjeVozisca': 'SUHO', 'VrstaVozisca': 'HRAPAV  ASFALT / BETON', 'GeoKoordinataX': '141318', 'GeoKoordinataY': '586601', 'ZaporednaStevilkaOsebeVPN': '1315001', 'Povzrocitelj': 'UDELEŽENEC', 'Starost': '30', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'ORMOŽ', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'POTNIK', 'UporabaVarnostnegaPasu': 'NE', 'VozniskiStazVLetih': '0', 'VozniskiStazVMesecih': '0', 'VrednostAlkotesta': '1.24', 'VrednostStrokovnegaPregleda': '0', 'Gostota prometa': 'do 1000'}
# {'\ufeffZaporednaStevilkaPN': '1315', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'ORMOŽ', 'DatumPN': '5.02.2011', 'UraPN': 'feb.55', 'VNaselju': 'NE', 'Lokacija': 'CESTA', 'VrstaCesteNaselja': 'GLAVNA CESTA', 'SifraCesteNaselja': '2', 'TekstCesteNaselja': 'SLOV.BISTRICA-SRED. OB DR', 'SifraOdsekaUlice': '250', 'TekstOdsekaUlice': 'SPUHLJA-ORMOŽ', 'StacionazaDogodka': '17000', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRILAGOJENA HITROST', 'TipNesrece': 'PREVRNITEV VOZILA', 'VremenskeOkoliscine': 'JASNO', 'StanjePrometa': 'REDEK', 'StanjeVozisca': 'SUHO', 'VrstaVozisca': 'HRAPAV  ASFALT / BETON', 'GeoKoordinataX': '141318', 'GeoKoordinataY': '586601', 'ZaporednaStevilkaOsebeVPN': '1315002', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '22', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'ORMOŽ', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'LAŽJA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'NE', 'VozniskiStazVLetih': '2', 'VozniskiStazVMesecih': '10', 'VrednostAlkotesta': '0', 'VrednostStrokovnegaPregleda': '1.63', 'Gostota prometa': 'do 1000'}
# {'\ufeffZaporednaStevilkaPN': '1392', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'IDRIJA', 'DatumPN': '4.02.2011', 'UraPN': '19.okt', 'VNaselju': 'DA', 'Lokacija': 'CESTA', 'VrstaCesteNaselja': 'GLAVNA CESTA II. REDA', 'SifraCesteNaselja': '102', 'TekstCesteNaselja': 'ROBIČ-IDRIJA-LOGATEC', 'SifraOdsekaUlice': '1036', 'TekstOdsekaUlice': 'ŽELIN-SP.IDRIJA MAROF', 'StacionazaDogodka': '100', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRAVILNA STRAN / SMER VOŽNJE', 'TipNesrece': 'ČELNO TRČENJE', 'VremenskeOkoliscine': 'JASNO', 'StanjePrometa': 'NORMALEN', 'StanjeVozisca': 'SUHO', 'VrstaVozisca': 'HRAPAV  ASFALT / BETON', 'GeoKoordinataX': '106939', 'GeoKoordinataY': '419148', 'ZaporednaStevilkaOsebeVPN': '1392002', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '25', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'TOLMIN', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'DA', 'VozniskiStazVLetih': '5', 'VozniskiStazVMesecih': '8', 'VrednostAlkotesta': '0', 'VrednostStrokovnegaPregleda': '0.04', 'Gostota prometa': 'nad 1000'}
# {'\ufeffZaporednaStevilkaPN': '1416', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'VELENJE', 'DatumPN': '6.02.2011', 'UraPN': '00.10', 'VNaselju': 'NE', 'Lokacija': 'CESTA', 'VrstaCesteNaselja': 'REGIONALNA CESTA II. REDA', 'SifraCesteNaselja': '425', 'TekstCesteNaselja': 'POLJANA-ŠENTVID-VELENJE', 'SifraOdsekaUlice': '1267', 'TekstOdsekaUlice': 'ŠOŠTANJ-PESJE', 'StacionazaDogodka': '1750', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRILAGOJENA HITROST', 'TipNesrece': 'ČELNO TRČENJE', 'VremenskeOkoliscine': 'JASNO', 'StanjePrometa': 'NORMALEN', 'StanjeVozisca': 'SUHO', 'VrstaVozisca': 'ZGLAJEN ASFALT / BETON', 'GeoKoordinataX': '136033', 'GeoKoordinataY': '505678', 'ZaporednaStevilkaOsebeVPN': '1416001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '37', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'VELENJE', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'NE', 'VozniskiStazVLetih': '0', 'VozniskiStazVMesecih': '0', 'VrednostAlkotesta': '0', 'VrednostStrokovnegaPregleda': '0.71', 'Gostota prometa': 'nad 10000'}
# {'\ufeffZaporednaStevilkaPN': '1477', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'GROSUPLJE', 'DatumPN': '5.02.2011', 'UraPN': 'dec.50', 'VNaselju': 'DA', 'Lokacija': 'NASELJE', 'VrstaCesteNaselja': 'NASELJE BREZ ULIČNEGA SISTEMA', 'SifraCesteNaselja': '9189', 'TekstCesteNaselja': 'VIDEM-DOBREPOLJE', 'SifraOdsekaUlice': '0', 'TekstOdsekaUlice': 'NI ODSEKOV', 'StacionazaDogodka': '29', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRILAGOJENA HITROST', 'TipNesrece': 'TRČENJE V OBJEKT', 'VremenskeOkoliscine': 'JASNO', 'StanjePrometa': 'NORMALEN', 'StanjeVozisca': 'SUHO', 'VrstaVozisca': 'ZGLAJEN ASFALT / BETON', 'GeoKoordinataX': '78584', 'GeoKoordinataY': '476526', 'ZaporednaStevilkaOsebeVPN': '1477001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '31', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'LITIJA', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'DA', 'VozniskiStazVLetih': '7', 'VozniskiStazVMesecih': '10', 'VrednostAlkotesta': '0.28', 'VrednostStrokovnegaPregleda': '0', 'Gostota prometa': 'nad 1000'}
# {'\ufeffZaporednaStevilkaPN': '1648', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'AJDOVŠČINA', 'DatumPN': '12.02.2011', 'UraPN': 'jul.30', 'VNaselju': 'NE', 'Lokacija': 'CESTA', 'VrstaCesteNaselja': 'REGIONALNA CESTA II. REDA', 'SifraCesteNaselja': '444', 'TekstCesteNaselja': 'RAZDRTO-SELO-ROŽNA DOLINA', 'SifraOdsekaUlice': '1473', 'TekstOdsekaUlice': 'VIPAVA-AJDOVŠČINA', 'StacionazaDogodka': '5700', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRAVILNA STRAN / SMER VOŽNJE', 'TipNesrece': 'TRČENJE V OBJEKT', 'VremenskeOkoliscine': 'OBLAČNO', 'StanjePrometa': 'REDEK', 'StanjeVozisca': 'SUHO', 'VrstaVozisca': 'ZGLAJEN ASFALT / BETON', 'GeoKoordinataX': '81659', 'GeoKoordinataY': '416663', 'ZaporednaStevilkaOsebeVPN': '1648002', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '19', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'AJDOVŠČINA', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'NE', 'VozniskiStazVLetih': '1', 'VozniskiStazVMesecih': '7', 'VrednostAlkotesta': '0', 'VrednostStrokovnegaPregleda': '0.75', 'Gostota prometa': 'nad 5000'}
# {'\ufeffZaporednaStevilkaPN': '1745', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'POSTOJNA', 'DatumPN': '12.02.2011', 'UraPN': 'feb.30', 'VNaselju': 'NE', 'Lokacija': 'CESTA', 'VrstaCesteNaselja': 'GLAVNA CESTA', 'SifraCesteNaselja': '6', 'TekstCesteNaselja': 'POSTOJNA-IL.BISTR-JELŠANE', 'SifraOdsekaUlice': '339', 'TekstOdsekaUlice': 'PIVKA-RIBNICA', 'StacionazaDogodka': '6854', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRAVILNA STRAN / SMER VOŽNJE', 'TipNesrece': 'TRČENJE V OBJEKT', 'VremenskeOkoliscine': 'OBLAČNO', 'StanjePrometa': 'REDEK', 'StanjeVozisca': 'SUHO', 'VrstaVozisca': 'HRAPAV  ASFALT / BETON', 'GeoKoordinataX': '56728', 'GeoKoordinataY': '434866', 'ZaporednaStevilkaOsebeVPN': '1745001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '19', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'POSTOJNA', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'NEZNANO', 'VozniskiStazVLetih': '0', 'VozniskiStazVMesecih': '0', 'VrednostAlkotesta': '0', 'VrednostStrokovnegaPregleda': '0.68', 'Gostota prometa': 'do 1000'}
# {'\ufeffZaporednaStevilkaPN': '1748', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'CELJE', 'DatumPN': '18.01.2011', 'UraPN': '15.15', 'VNaselju': 'DA', 'Lokacija': 'NASELJE', 'VrstaCesteNaselja': 'NASELJE Z ULIČNIM SISTEMOM', 'SifraCesteNaselja': '3011', 'TekstCesteNaselja': 'CELJE', 'SifraOdsekaUlice': '18', 'TekstOdsekaUlice': 'CESTA V LAŠKO', 'StacionazaDogodka': '5', 'OpisKraja': 'KRIŽIŠČE', 'VzrokNesrece': 'NEUPOŠTEVANJE PRAVIL O PREDNOSTI', 'TipNesrece': 'BOČNO TRČENJE', 'VremenskeOkoliscine': 'JASNO', 'StanjePrometa': 'GOST', 'StanjeVozisca': 'SUHO', 'VrstaVozisca': 'HRAPAV  ASFALT / BETON', 'GeoKoordinataX': '119176', 'GeoKoordinataY': '520587', 'ZaporednaStevilkaOsebeVPN': '1748003', 'Povzrocitelj': 'UDELEŽENEC', 'Starost': '60', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'CELJE', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'PEŠEC', 'UporabaVarnostnegaPasu': 'NE', 'VozniskiStazVLetih': '0', 'VozniskiStazVMesecih': '0', 'VrednostAlkotesta': '0.46', 'VrednostStrokovnegaPregleda': '0', 'Gostota prometa': 'nad 10000'}
# {'\ufeffZaporednaStevilkaPN': '1875', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'ZAGORJE OB SAVI', 'DatumPN': '10.02.2011', 'UraPN': '08.00', 'VNaselju': 'DA', 'Lokacija': 'NASELJE', 'VrstaCesteNaselja': 'NASELJE BREZ ULIČNEGA SISTEMA', 'SifraCesteNaselja': '61031', 'TekstCesteNaselja': 'LOKE PRI ZAGORJU', 'SifraOdsekaUlice': '0', 'TekstOdsekaUlice': 'NI ODSEKOV', 'StacionazaDogodka': '3', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRILAGOJENA HITROST', 'TipNesrece': 'ČELNO TRČENJE', 'VremenskeOkoliscine': 'OBLAČNO', 'StanjePrometa': 'NORMALEN', 'StanjeVozisca': 'MOKRO', 'VrstaVozisca': 'ZGLAJEN ASFALT / BETON', 'GeoKoordinataX': '110843', 'GeoKoordinataY': '498699', 'ZaporednaStevilkaOsebeVPN': '1875001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '31', 'Spol': 'ŽENSKI', 'UEStalnegaPrebivalisca': 'ZAGORJE OB SAVI', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'LAŽJA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'DA', 'VozniskiStazVLetih': '2', 'VozniskiStazVMesecih': '7', 'VrednostAlkotesta': '0', 'VrednostStrokovnegaPregleda': '1.31', 'Gostota prometa': 'nad 5000'}
# {'\ufeffZaporednaStevilkaPN': '1994', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'LJUBLJANA', 'DatumPN': '8.02.2011', 'UraPN': '15.00', 'VNaselju': 'DA', 'Lokacija': 'NASELJE', 'VrstaCesteNaselja': 'NASELJE BREZ ULIČNEGA SISTEMA', 'SifraCesteNaselja': '28060', 'TekstCesteNaselja': 'JEZERO-BREZOVICA', 'SifraOdsekaUlice': '0', 'TekstOdsekaUlice': 'NI ODSEKOV', 'StacionazaDogodka': '69', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRILAGOJENA HITROST', 'TipNesrece': 'PREVRNITEV VOZILA', 'VremenskeOkoliscine': 'JASNO', 'StanjePrometa': 'REDEK', 'StanjeVozisca': 'SUHO', 'VrstaVozisca': 'MAKADAM', 'GeoKoordinataX': '91079', 'GeoKoordinataY': '456899', 'ZaporednaStevilkaOsebeVPN': '1994001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '23', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'LJUBLJANA', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK ŠTIRIKOLESA', 'UporabaVarnostnegaPasu': 'DA', 'VozniskiStazVLetih': '4', 'VozniskiStazVMesecih': '9', 'VrednostAlkotesta': '0.06', 'VrednostStrokovnegaPregleda': '0', 'Gostota prometa': 'do 1000'}
# {'\ufeffZaporednaStevilkaPN': '2068', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'KOČEVJE', 'DatumPN': '16.02.2011', 'UraPN': '17.55', 'VNaselju': 'NE', 'Lokacija': 'CESTA', 'VrstaCesteNaselja': 'GLAVNA CESTA II. REDA', 'SifraCesteNaselja': '106', 'TekstCesteNaselja': 'LJ JUG-ŠKOFLJICA-ŠM.SAP', 'SifraOdsekaUlice': '265', 'TekstOdsekaUlice': 'LIVOLD-FARA', 'StacionazaDogodka': '1000', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRILAGOJENA HITROST', 'TipNesrece': 'OSTALO', 'VremenskeOkoliscine': 'OBLAČNO', 'StanjePrometa': 'REDEK', 'StanjeVozisca': 'MOKRO', 'VrstaVozisca': 'HRAPAV  ASFALT / BETON', 'GeoKoordinataX': '51029', 'GeoKoordinataY': '491666', 'ZaporednaStevilkaOsebeVPN': '2068001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '36', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'KOČEVJE', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'DA', 'VozniskiStazVLetih': '6', 'VozniskiStazVMesecih': '9', 'VrednostAlkotesta': '0', 'VrednostStrokovnegaPregleda': '0.7', 'Gostota prometa': '0'}
# {'\ufeffZaporednaStevilkaPN': '2068', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'KOČEVJE', 'DatumPN': '16.02.2011', 'UraPN': '17.55', 'VNaselju': 'NE', 'Lokacija': 'CESTA', 'VrstaCesteNaselja': 'GLAVNA CESTA II. REDA', 'SifraCesteNaselja': '106', 'TekstCesteNaselja': 'LJ JUG-ŠKOFLJICA-ŠM.SAP', 'SifraOdsekaUlice': '265', 'TekstOdsekaUlice': 'LIVOLD-FARA', 'StacionazaDogodka': '1000', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRILAGOJENA HITROST', 'TipNesrece': 'OSTALO', 'VremenskeOkoliscine': 'OBLAČNO', 'StanjePrometa': 'REDEK', 'StanjeVozisca': 'MOKRO', 'VrstaVozisca': 'HRAPAV  ASFALT / BETON', 'GeoKoordinataX': '51029', 'GeoKoordinataY': '491666', 'ZaporednaStevilkaOsebeVPN': '2068002', 'Povzrocitelj': 'UDELEŽENEC', 'Starost': '44', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'KOČEVJE', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'LAŽJA TELESNA POŠKODBA', 'VrstaUdelezenca': 'POTNIK', 'UporabaVarnostnegaPasu': 'DA', 'VozniskiStazVLetih': '0', 'VozniskiStazVMesecih': '0', 'VrednostAlkotesta': '0', 'VrednostStrokovnegaPregleda': '1.99', 'Gostota prometa': '0'}
# {'\ufeffZaporednaStevilkaPN': '2312', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'KRŠKO', 'DatumPN': '6.02.2011', 'UraPN': '15.15', 'VNaselju': 'NE', 'Lokacija': 'CESTA', 'VrstaCesteNaselja': 'LOKALNA CESTA', 'SifraCesteNaselja': '19508', 'TekstCesteNaselja': '191161 ZABUK. - MEJA ŠKOC', 'SifraOdsekaUlice': '19508', 'TekstOdsekaUlice': 'NI ODSEKA', 'StacionazaDogodka': '0', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEUPOŠTEVANJE PRAVIL O PREDNOSTI', 'TipNesrece': 'BOČNO TRČENJE', 'VremenskeOkoliscine': 'JASNO', 'StanjePrometa': 'NORMALEN', 'StanjeVozisca': 'SUHO', 'VrstaVozisca': 'ZGLAJEN ASFALT / BETON', 'GeoKoordinataX': '0', 'GeoKoordinataY': '0', 'ZaporednaStevilkaOsebeVPN': '2312001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '44', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'KRŠKO', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'BREZ POŠKODBE', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'DA', 'VozniskiStazVLetih': '16', 'VozniskiStazVMesecih': '3', 'VrednostAlkotesta': '0.19', 'VrednostStrokovnegaPregleda': '0.06', 'Gostota prometa': '0'}
# {'\ufeffZaporednaStevilkaPN': '2370', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'NOVO MESTO', 'DatumPN': '8.02.2011', 'UraPN': '16.15', 'VNaselju': 'DA', 'Lokacija': 'NASELJE', 'VrstaCesteNaselja': 'NASELJE BREZ ULIČNEGA SISTEMA', 'SifraCesteNaselja': '38348', 'TekstCesteNaselja': 'ŽALOVIČE', 'SifraOdsekaUlice': '0', 'TekstOdsekaUlice': 'NI ODSEKOV', 'StacionazaDogodka': '1', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRILAGOJENA HITROST', 'TipNesrece': 'PREVRNITEV VOZILA', 'VremenskeOkoliscine': 'JASNO', 'StanjePrometa': 'REDEK', 'StanjeVozisca': 'SUHO', 'VrstaVozisca': 'HRAPAV  ASFALT / BETON', 'GeoKoordinataX': '80395', 'GeoKoordinataY': '517748', 'ZaporednaStevilkaOsebeVPN': '2370001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '49', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'NOVO MESTO', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK ŠTIRIKOLESA', 'UporabaVarnostnegaPasu': 'NE', 'VozniskiStazVLetih': '14', 'VozniskiStazVMesecih': '3', 'VrednostAlkotesta': '0.72', 'VrednostStrokovnegaPregleda': '0', 'Gostota prometa': '0'}
# {'\ufeffZaporednaStevilkaPN': '2618', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'POSTOJNA', 'DatumPN': '2.03.2011', 'UraPN': '13.40', 'VNaselju': 'NE', 'Lokacija': 'CESTA', 'VrstaCesteNaselja': 'TURISTIČNA CESTA', 'SifraCesteNaselja': '913', 'TekstCesteNaselja': 'POSTOJNA-ERAZEM-PREDJAMA', 'SifraOdsekaUlice': '6105', 'TekstOdsekaUlice': 'POSTOJNA-MOTEL ERAZEM', 'StacionazaDogodka': '5749', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRAVILNO PREHITEVANJE', 'TipNesrece': 'OPLAŽENJE', 'VremenskeOkoliscine': 'SNEG', 'StanjePrometa': 'REDEK', 'StanjeVozisca': 'SPOLZKO', 'VrstaVozisca': 'HRAPAV  ASFALT / BETON', 'GeoKoordinataX': '73981', 'GeoKoordinataY': '435112', 'ZaporednaStevilkaOsebeVPN': '2618003', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '27', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'POSTOJNA', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'LAŽJA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'DA', 'VozniskiStazVLetih': '7', 'VozniskiStazVMesecih': '11', 'VrednostAlkotesta': '0.6', 'VrednostStrokovnegaPregleda': '0', 'Gostota prometa': '0'}
# {'\ufeffZaporednaStevilkaPN': '2651', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'PIRAN', 'DatumPN': '18.02.2011', 'UraPN': '13.30', 'VNaselju': 'NE', 'Lokacija': 'CESTA', 'VrstaCesteNaselja': 'GLAVNA CESTA II. REDA', 'SifraCesteNaselja': '111', 'TekstCesteNaselja': 'KOPER - SEČOVLJE', 'SifraOdsekaUlice': '373', 'TekstOdsekaUlice': 'IZOLA-JAGODJE', 'StacionazaDogodka': '6092', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRAVILNA STRAN / SMER VOŽNJE', 'TipNesrece': 'ČELNO TRČENJE', 'VremenskeOkoliscine': 'JASNO', 'StanjePrometa': 'NORMALEN', 'StanjeVozisca': 'SUHO', 'VrstaVozisca': 'ZGLAJEN ASFALT / BETON', 'GeoKoordinataX': '43475', 'GeoKoordinataY': '392596', 'ZaporednaStevilkaOsebeVPN': '2651001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '24', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'IZOLA', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'KOLESAR', 'UporabaVarnostnegaPasu': 'NE', 'VozniskiStazVLetih': '0', 'VozniskiStazVMesecih': '0', 'VrednostAlkotesta': '0', 'VrednostStrokovnegaPregleda': '1.18', 'Gostota prometa': 'nad 20000'}
# {'\ufeffZaporednaStevilkaPN': '2787', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'ŽALEC', 'DatumPN': '26.02.2011', 'UraPN': '21.00', 'VNaselju': 'DA', 'Lokacija': 'NASELJE', 'VrstaCesteNaselja': 'NASELJE BREZ ULIČNEGA SISTEMA', 'SifraCesteNaselja': '62030', 'TekstCesteNaselja': 'KAPLJA VAS-PREBOLD', 'SifraOdsekaUlice': '0', 'TekstOdsekaUlice': 'NI ODSEKOV', 'StacionazaDogodka': '21', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRILAGOJENA HITROST', 'TipNesrece': 'ČELNO TRČENJE', 'VremenskeOkoliscine': 'JASNO', 'StanjePrometa': 'REDEK', 'StanjeVozisca': 'SUHO', 'VrstaVozisca': 'ZGLAJEN ASFALT / BETON', 'GeoKoordinataX': '122082', 'GeoKoordinataY': '506401', 'ZaporednaStevilkaOsebeVPN': '2787001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '29', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'ŽALEC', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'NE', 'VozniskiStazVLetih': '6', 'VozniskiStazVMesecih': '7', 'VrednostAlkotesta': '0', 'VrednostStrokovnegaPregleda': '2.28', 'Gostota prometa': '0'}
# {'\ufeffZaporednaStevilkaPN': '3041', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'KRANJ', 'DatumPN': '9.03.2011', 'UraPN': '16.40', 'VNaselju': 'DA', 'Lokacija': 'NASELJE', 'VrstaCesteNaselja': 'NASELJE Z ULIČNIM SISTEMOM', 'SifraCesteNaselja': '18035', 'TekstCesteNaselja': 'KRANJ', 'SifraOdsekaUlice': '84', 'TekstOdsekaUlice': 'SAVSKA CESTA', 'StacionazaDogodka': '2', 'OpisKraja': 'KROŽNO KRIŽIŠČE', 'VzrokNesrece': 'OSTALO', 'TipNesrece': 'PREVRNITEV VOZILA', 'VremenskeOkoliscine': 'JASNO', 'StanjePrometa': 'NORMALEN', 'StanjeVozisca': 'SUHO', 'VrstaVozisca': 'ZGLAJEN ASFALT / BETON', 'GeoKoordinataX': '121716', 'GeoKoordinataY': '450500', 'ZaporednaStevilkaOsebeVPN': '3041001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '69', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'KRANJ', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK KOLESA Z MOTORJEM', 'UporabaVarnostnegaPasu': 'DA', 'VozniskiStazVLetih': '50', 'VozniskiStazVMesecih': '4', 'VrednostAlkotesta': '0.56', 'VrednostStrokovnegaPregleda': '0', 'Gostota prometa': 'do 1000'}
# {'\ufeffZaporednaStevilkaPN': '3096', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'VRHNIKA', 'DatumPN': '9.03.2011', 'UraPN': '16.okt', 'VNaselju': 'DA', 'Lokacija': 'CESTA', 'VrstaCesteNaselja': 'REGIONALNA CESTA II. REDA', 'SifraCesteNaselja': '409', 'TekstCesteNaselja': 'LJ VIČ-VRHNIKA-LOGATEC', 'SifraOdsekaUlice': '300', 'TekstOdsekaUlice': 'BREZOVICA-VRHNIKA', 'StacionazaDogodka': '4700', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRAVILNO PREHITEVANJE', 'TipNesrece': 'OPLAŽENJE', 'VremenskeOkoliscine': 'JASNO', 'StanjePrometa': 'NORMALEN', 'StanjeVozisca': 'SUHO', 'VrstaVozisca': 'HRAPAV  ASFALT / BETON', 'GeoKoordinataX': '96705', 'GeoKoordinataY': '452237', 'ZaporednaStevilkaOsebeVPN': '3096001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '36', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'KAMNIK', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK MOTORNEGA KOLESA', 'UporabaVarnostnegaPasu': 'DA', 'VozniskiStazVLetih': '10', 'VozniskiStazVMesecih': '4', 'VrednostAlkotesta': '0.06', 'VrednostStrokovnegaPregleda': '0', 'Gostota prometa': 'nad 20000'}
# {'\ufeffZaporednaStevilkaPN': '3186', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'MURSKA SOBOTA', 'DatumPN': '21.02.2011', 'UraPN': '10.maj', 'VNaselju': 'NE', 'Lokacija': 'CESTA', 'VrstaCesteNaselja': 'REGIONALNA CESTA II. REDA', 'SifraCesteNaselja': '441', 'TekstCesteNaselja': 'MURSKA SOBOTA - GEDEROVCI', 'SifraOdsekaUlice': '1298', 'TekstOdsekaUlice': 'MURSKA SOBOTA-GEDEROVCI', 'StacionazaDogodka': '5000', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRAVILNA STRAN / SMER VOŽNJE', 'TipNesrece': 'ČELNO TRČENJE', 'VremenskeOkoliscine': 'SNEG', 'StanjePrometa': 'NORMALEN', 'StanjeVozisca': 'MOKRO', 'VrstaVozisca': 'HRAPAV  ASFALT / BETON', 'GeoKoordinataX': '169818', 'GeoKoordinataY': '585609', 'ZaporednaStevilkaOsebeVPN': '3186002', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '46', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'MURSKA SOBOTA', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'DA', 'VozniskiStazVLetih': '28', 'VozniskiStazVMesecih': '9', 'VrednostAlkotesta': '0', 'VrednostStrokovnegaPregleda': '0.05', 'Gostota prometa': '0'}
# {'\ufeffZaporednaStevilkaPN': '3577', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'KOPER', 'DatumPN': '20.03.2011', 'UraPN': '22.55', 'VNaselju': 'DA', 'Lokacija': 'CESTA', 'VrstaCesteNaselja': 'LOKALNA CESTA', 'SifraCesteNaselja': '93712', 'TekstCesteNaselja': 'DEKANI-SV ANTON', 'SifraOdsekaUlice': '93712', 'TekstOdsekaUlice': 'NI ODSEKOV', 'StacionazaDogodka': '1300', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRILAGOJENA HITROST', 'TipNesrece': 'TRČENJE V OBJEKT', 'VremenskeOkoliscine': 'JASNO', 'StanjePrometa': 'REDEK', 'StanjeVozisca': 'SUHO', 'VrstaVozisca': 'HRAPAV  ASFALT / BETON', 'GeoKoordinataX': '45704', 'GeoKoordinataY': '407571', 'ZaporednaStevilkaOsebeVPN': '3577001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '31', 'Spol': 'ŽENSKI', 'UEStalnegaPrebivalisca': 'KOPER', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'LAŽJA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'DA', 'VozniskiStazVLetih': '13', 'VozniskiStazVMesecih': '6', 'VrednostAlkotesta': '0.09', 'VrednostStrokovnegaPregleda': '0', 'Gostota prometa': 'nad 5000'}
# {'\ufeffZaporednaStevilkaPN': '3623', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'PIRAN', 'DatumPN': '21.03.2011', 'UraPN': '12.okt', 'VNaselju': 'NE', 'Lokacija': 'CESTA', 'VrstaCesteNaselja': 'LOKALNA CESTA', 'SifraCesteNaselja': '93308', 'TekstCesteNaselja': '140050 MALIJA-LUCIJA', 'SifraOdsekaUlice': '93308', 'TekstOdsekaUlice': 'NI ODSEKOV', 'StacionazaDogodka': '400', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRILAGOJENA HITROST', 'TipNesrece': 'PREVRNITEV VOZILA', 'VremenskeOkoliscine': 'JASNO', 'StanjePrometa': 'REDEK', 'StanjeVozisca': 'SPOLZKO', 'VrstaVozisca': 'ZGLAJEN ASFALT / BETON', 'GeoKoordinataX': '40848', 'GeoKoordinataY': '392204', 'ZaporednaStevilkaOsebeVPN': '3623001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '53', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'IZOLA', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK KOLESA Z MOTORJEM', 'UporabaVarnostnegaPasu': 'NE', 'VozniskiStazVLetih': '0', 'VozniskiStazVMesecih': '0', 'VrednostAlkotesta': '0', 'VrednostStrokovnegaPregleda': '2.23', 'Gostota prometa': 'nad 10000'}
# {'\ufeffZaporednaStevilkaPN': '3716', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'JESENICE', 'DatumPN': '19.02.2011', 'UraPN': '23.35', 'VNaselju': 'DA', 'Lokacija': 'NASELJE', 'VrstaCesteNaselja': 'NASELJE BREZ ULIČNEGA SISTEMA', 'SifraCesteNaselja': '14003', 'TekstCesteNaselja': 'BREG-ŽIROVNICA', 'SifraOdsekaUlice': '0', 'TekstOdsekaUlice': 'NI ODSEKOV', 'StacionazaDogodka': '3', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRILAGOJENA HITROST', 'TipNesrece': 'TRČENJE V OBJEKT', 'VremenskeOkoliscine': 'OBLAČNO', 'StanjePrometa': 'REDEK', 'StanjeVozisca': 'BLATNO', 'VrstaVozisca': 'MAKADAM', 'GeoKoordinataX': '138904', 'GeoKoordinataY': '432913', 'ZaporednaStevilkaOsebeVPN': '3716001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '23', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'RADOVLJICA', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'DA', 'VozniskiStazVLetih': '5', 'VozniskiStazVMesecih': '9', 'VrednostAlkotesta': '0', 'VrednostStrokovnegaPregleda': '0.38', 'Gostota prometa': 'nad 5000'}
# ...
# {'\ufeffZaporednaStevilkaPN': '13429', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'NOVO MESTO', 'DatumPN': '13.11.2020', 'UraPN': '15.20', 'VNaselju': 'DA', 'Lokacija': 'NASELJE', 'VrstaCesteNaselja': 'NASELJE BREZ ULIČNEGA SISTEMA', 'SifraCesteNaselja': '38323', 'TekstCesteNaselja': 'VOLČKOVA VAS', 'SifraOdsekaUlice': '0', 'TekstOdsekaUlice': 'NI ODSEKOV', 'StacionazaDogodka': '2', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'OSTALO', 'TipNesrece': 'OSTALO', 'VremenskeOkoliscine': 'OBLAČNO', 'StanjePrometa': 'REDEK', 'StanjeVozisca': 'SUHO', 'VrstaVozisca': 'ZGLAJEN ASFALT / BETON', 'GeoKoordinataX': '76658', 'GeoKoordinataY': '528101', 'ZaporednaStevilkaOsebeVPN': '13429001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '62', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'NOVO MESTO', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'KOLESAR', 'UporabaVarnostnegaPasu': 'NE', 'VozniskiStazVLetih': '0', 'VozniskiStazVMesecih': '0', 'VrednostAlkotesta': '1.47', 'VrednostStrokovnegaPregleda': '0', 'Gostota prometa': '0'}
# {'\ufeffZaporednaStevilkaPN': '13456', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'GROSUPLJE', 'DatumPN': '14.11.2020', 'UraPN': '21.avg', 'VNaselju': 'NE', 'Lokacija': 'CESTA', 'VrstaCesteNaselja': 'REGIONALNA CESTA II. REDA', 'SifraCesteNaselja': '448', 'TekstCesteNaselja': 'IV.GORICA-TREBNJE-DOBRAVA', 'SifraOdsekaUlice': '1196', 'TekstOdsekaUlice': 'IVANČNA GORICA-GRM', 'StacionazaDogodka': '3500', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRAVILNA STRAN / SMER VOŽNJE', 'TipNesrece': 'TRČENJE V OBJEKT', 'VremenskeOkoliscine': 'OBLAČNO', 'StanjePrometa': 'REDEK', 'StanjeVozisca': 'MOKRO', 'VrstaVozisca': 'HRAPAV  ASFALT / BETON', 'GeoKoordinataX': '89351', 'GeoKoordinataY': '487932', 'ZaporednaStevilkaOsebeVPN': '13456001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '30', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'GROSUPLJE', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'DA', 'VozniskiStazVLetih': '11', 'VozniskiStazVMesecih': '6', 'VrednostAlkotesta': '0', 'VrednostStrokovnegaPregleda': '1.06', 'Gostota prometa': 'nad 5000'}
# {'\ufeffZaporednaStevilkaPN': '13456', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'GROSUPLJE', 'DatumPN': '14.11.2020', 'UraPN': '21.avg', 'VNaselju': 'NE', 'Lokacija': 'CESTA', 'VrstaCesteNaselja': 'REGIONALNA CESTA II. REDA', 'SifraCesteNaselja': '448', 'TekstCesteNaselja': 'IV.GORICA-TREBNJE-DOBRAVA', 'SifraOdsekaUlice': '1196', 'TekstOdsekaUlice': 'IVANČNA GORICA-GRM', 'StacionazaDogodka': '3500', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRAVILNA STRAN / SMER VOŽNJE', 'TipNesrece': 'TRČENJE V OBJEKT', 'VremenskeOkoliscine': 'OBLAČNO', 'StanjePrometa': 'REDEK', 'StanjeVozisca': 'MOKRO', 'VrstaVozisca': 'HRAPAV  ASFALT / BETON', 'GeoKoordinataX': '89351', 'GeoKoordinataY': '487932', 'ZaporednaStevilkaOsebeVPN': '13456002', 'Povzrocitelj': 'UDELEŽENEC', 'Starost': '27', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'GROSUPLJE', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'LAŽJA TELESNA POŠKODBA', 'VrstaUdelezenca': 'POTNIK', 'UporabaVarnostnegaPasu': 'NE', 'VozniskiStazVLetih': '0', 'VozniskiStazVMesecih': '0', 'VrednostAlkotesta': '0', 'VrednostStrokovnegaPregleda': '2.52', 'Gostota prometa': 'nad 5000'}
# {'\ufeffZaporednaStevilkaPN': '13601', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'NOVO MESTO', 'DatumPN': '20.11.2020', 'UraPN': '21.maj', 'VNaselju': 'NE', 'Lokacija': 'CESTA', 'VrstaCesteNaselja': 'REGIONALNA CESTA', 'SifraCesteNaselja': '216', 'TekstCesteNaselja': 'IVANČNA GORICA - ČRNOMELJ', 'SifraOdsekaUlice': '1175', 'TekstOdsekaUlice': 'KRKA-ŽUŽEMBERK', 'StacionazaDogodka': '13378', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRILAGOJENA HITROST', 'TipNesrece': 'TRČENJE V OBJEKT', 'VremenskeOkoliscine': 'JASNO', 'StanjePrometa': 'REDEK', 'StanjeVozisca': 'SUHO', 'VrstaVozisca': 'HRAPAV  ASFALT / BETON', 'GeoKoordinataX': '76292', 'GeoKoordinataY': '495077', 'ZaporednaStevilkaOsebeVPN': '13601001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '17', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'NOVO MESTO', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK MOPEDA', 'UporabaVarnostnegaPasu': 'DA', 'VozniskiStazVLetih': '0', 'VozniskiStazVMesecih': '0', 'VrednostAlkotesta': '0', 'VrednostStrokovnegaPregleda': '0.81', 'Gostota prometa': 'nad 1000'}
# {'\ufeffZaporednaStevilkaPN': '13603', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'PESNICA', 'DatumPN': '21.11.2020', 'UraPN': '15.okt', 'VNaselju': 'DA', 'Lokacija': 'NASELJE', 'VrstaCesteNaselja': 'NASELJE BREZ ULIČNEGA SISTEMA', 'SifraCesteNaselja': '65065', 'TekstCesteNaselja': 'ZGORNJI JAKOBSKI DOL', 'SifraOdsekaUlice': '0', 'TekstOdsekaUlice': 'NI ODSEKOV', 'StacionazaDogodka': '2', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRAVILNA STRAN / SMER VOŽNJE', 'TipNesrece': 'POVOŽENJE PEŠCA', 'VremenskeOkoliscine': 'JASNO', 'StanjePrometa': 'NORMALEN', 'StanjeVozisca': 'SUHO', 'VrstaVozisca': 'HRAPAV  ASFALT / BETON', 'GeoKoordinataX': '165467', 'GeoKoordinataY': '556407', 'ZaporednaStevilkaOsebeVPN': '13603001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '37', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'PESNICA', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'BREZ POŠKODBE', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'DA', 'VozniskiStazVLetih': '19', 'VozniskiStazVMesecih': '4', 'VrednostAlkotesta': '0.03', 'VrednostStrokovnegaPregleda': '0', 'Gostota prometa': 'do 1000'}
# {'\ufeffZaporednaStevilkaPN': '14272', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'MURSKA SOBOTA', 'DatumPN': '13.12.2020', 'UraPN': '20.20', 'VNaselju': 'NE', 'Lokacija': 'CESTA', 'VrstaCesteNaselja': 'LOKALNA CESTA', 'SifraCesteNaselja': '95605', 'TekstCesteNaselja': 'IŽAKOVCI-BELTINCI', 'SifraOdsekaUlice': '0', 'TekstOdsekaUlice': 'NI ODSEKOV', 'StacionazaDogodka': '0', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRILAGOJENA HITROST', 'TipNesrece': 'TRČENJE V OBJEKT', 'VremenskeOkoliscine': 'JASNO', 'StanjePrometa': 'REDEK', 'StanjeVozisca': 'SPOLZKO', 'VrstaVozisca': 'ZGLAJEN ASFALT / BETON', 'GeoKoordinataX': '160702', 'GeoKoordinataY': '593616', 'ZaporednaStevilkaOsebeVPN': '14272001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '32', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'MURSKA SOBOTA', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'DA', 'VozniskiStazVLetih': '7', 'VozniskiStazVMesecih': '7', 'VrednostAlkotesta': '0', 'VrednostStrokovnegaPregleda': '1.66', 'Gostota prometa': '0'}
# {'\ufeffZaporednaStevilkaPN': '14324', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'ŽALEC', 'DatumPN': '14.12.2020', 'UraPN': '00.15', 'VNaselju': 'NE', 'Lokacija': 'CESTA', 'VrstaCesteNaselja': 'REGIONALNA CESTA II. REDA', 'SifraCesteNaselja': '427', 'TekstCesteNaselja': 'LATKOVA VAS-TRBOVLJE', 'SifraOdsekaUlice': '1351', 'TekstOdsekaUlice': 'LATKOVA VAS-TRBOVLJE', 'StacionazaDogodka': '9000', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRILAGOJENA HITROST', 'TipNesrece': 'ČELNO TRČENJE', 'VremenskeOkoliscine': 'JASNO', 'StanjePrometa': 'REDEK', 'StanjeVozisca': 'MOKRO', 'VrstaVozisca': 'HRAPAV  ASFALT / BETON', 'GeoKoordinataX': '116769', 'GeoKoordinataY': '505673', 'ZaporednaStevilkaOsebeVPN': '14324001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '23', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'ŽALEC', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'BREZ POŠKODBE', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'DA', 'VozniskiStazVLetih': '0', 'VozniskiStazVMesecih': '0', 'VrednostAlkotesta': '0.53', 'VrednostStrokovnegaPregleda': '1.04', 'Gostota prometa': 'nad 1000'}
# {'\ufeffZaporednaStevilkaPN': '14546', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'KRŠKO', 'DatumPN': '7.12.2020', 'UraPN': '17.45', 'VNaselju': 'DA', 'Lokacija': 'NASELJE', 'VrstaCesteNaselja': 'NASELJE Z ULIČNIM SISTEMOM', 'SifraCesteNaselja': '19085', 'TekstCesteNaselja': 'KRŠKO', 'SifraOdsekaUlice': '55', 'TekstOdsekaUlice': 'TOVARNIŠKA ULICA', 'StacionazaDogodka': '8', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRAVILNOSTI PEŠCA', 'TipNesrece': 'POVOŽENJE PEŠCA', 'VremenskeOkoliscine': 'DEŽEVNO', 'StanjePrometa': 'NORMALEN', 'StanjeVozisca': 'MOKRO', 'VrstaVozisca': 'ZGLAJEN ASFALT / BETON', 'GeoKoordinataX': '90524', 'GeoKoordinataY': '538347', 'ZaporednaStevilkaOsebeVPN': '14546001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '32', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'KRŠKO', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'PEŠEC', 'UporabaVarnostnegaPasu': 'NE', 'VozniskiStazVLetih': '0', 'VozniskiStazVMesecih': '0', 'VrednostAlkotesta': '0', 'VrednostStrokovnegaPregleda': '1.85', 'Gostota prometa': 'nad 20000'}
# {'\ufeffZaporednaStevilkaPN': '14673', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'LJUBLJANA', 'DatumPN': '12.12.2020', 'UraPN': '23.43', 'VNaselju': 'DA', 'Lokacija': 'NASELJE', 'VrstaCesteNaselja': 'NASELJE Z ULIČNIM SISTEMOM', 'SifraCesteNaselja': '28050', 'TekstCesteNaselja': 'HORJUL', 'SifraOdsekaUlice': '7', 'TekstOdsekaUlice': 'LJUBLJANSKA CESTA', 'StacionazaDogodka': '65', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEUPOŠTEVANJE PRAVIL O PREDNOSTI', 'TipNesrece': 'BOČNO TRČENJE', 'VremenskeOkoliscine': 'OBLAČNO', 'StanjePrometa': 'REDEK', 'StanjeVozisca': 'MOKRO', 'VrstaVozisca': 'HRAPAV  ASFALT / BETON', 'GeoKoordinataX': '97839', 'GeoKoordinataY': '446080', 'ZaporednaStevilkaOsebeVPN': '14673001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '23', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'LJUBLJANA', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'KOLESAR', 'UporabaVarnostnegaPasu': 'NE', 'VozniskiStazVLetih': '0', 'VozniskiStazVMesecih': '0', 'VrednostAlkotesta': '0', 'VrednostStrokovnegaPregleda': '1.69', 'Gostota prometa': 'do 1000'}
# {'\ufeffZaporednaStevilkaPN': '14673', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'LJUBLJANA', 'DatumPN': '12.12.2020', 'UraPN': '23.43', 'VNaselju': 'DA', 'Lokacija': 'NASELJE', 'VrstaCesteNaselja': 'NASELJE Z ULIČNIM SISTEMOM', 'SifraCesteNaselja': '28050', 'TekstCesteNaselja': 'HORJUL', 'SifraOdsekaUlice': '7', 'TekstOdsekaUlice': 'LJUBLJANSKA CESTA', 'StacionazaDogodka': '65', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEUPOŠTEVANJE PRAVIL O PREDNOSTI', 'TipNesrece': 'BOČNO TRČENJE', 'VremenskeOkoliscine': 'OBLAČNO', 'StanjePrometa': 'REDEK', 'StanjeVozisca': 'MOKRO', 'VrstaVozisca': 'HRAPAV  ASFALT / BETON', 'GeoKoordinataX': '97839', 'GeoKoordinataY': '446080', 'ZaporednaStevilkaOsebeVPN': '14673002', 'Povzrocitelj': 'UDELEŽENEC', 'Starost': '38', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'LJUBLJANA', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'LAŽJA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'DA', 'VozniskiStazVLetih': '20', 'VozniskiStazVMesecih': '1', 'VrednostAlkotesta': '0.28', 'VrednostStrokovnegaPregleda': '0', 'Gostota prometa': 'do 1000'}
# {'\ufeffZaporednaStevilkaPN': '14733', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'TOLMIN', 'DatumPN': '25.12.2020', 'UraPN': '00.20', 'VNaselju': 'NE', 'Lokacija': 'CESTA', 'VrstaCesteNaselja': 'LOKALNA CESTA', 'SifraCesteNaselja': '99032', 'TekstCesteNaselja': 'ZADLAZ Ž - TOL RAVNE', 'SifraOdsekaUlice': '0', 'TekstOdsekaUlice': 'NI ODSEKOV', 'StacionazaDogodka': '2100', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRILAGOJENA HITROST', 'TipNesrece': 'ČELNO TRČENJE', 'VremenskeOkoliscine': 'OBLAČNO', 'StanjePrometa': 'REDEK', 'StanjeVozisca': 'MOKRO', 'VrstaVozisca': 'HRAPAV  ASFALT / BETON', 'GeoKoordinataX': '0', 'GeoKoordinataY': '0', 'ZaporednaStevilkaOsebeVPN': '14733002', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '17', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'TOLMIN', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'NE', 'VozniskiStazVLetih': '0', 'VozniskiStazVMesecih': '0', 'VrednostAlkotesta': '0', 'VrednostStrokovnegaPregleda': '0.67', 'Gostota prometa': '0'}
# {'\ufeffZaporednaStevilkaPN': '14837', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'NOVO MESTO', 'DatumPN': '30.12.2020', 'UraPN': '17.maj', 'VNaselju': 'NE', 'Lokacija': 'CESTA', 'VrstaCesteNaselja': 'REGIONALNA CESTA II. REDA', 'SifraCesteNaselja': '419', 'TekstCesteNaselja': 'SOTESKA-NM-ČATEŽ OB SAVI', 'SifraOdsekaUlice': '1203', 'TekstOdsekaUlice': 'SOTESKA-NOVO MESTO', 'StacionazaDogodka': '11066', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRAVILNA STRAN / SMER VOŽNJE', 'TipNesrece': 'TRČENJE V OBJEKT', 'VremenskeOkoliscine': 'OBLAČNO', 'StanjePrometa': 'NORMALEN', 'StanjeVozisca': 'MOKRO', 'VrstaVozisca': 'HRAPAV  ASFALT / BETON', 'GeoKoordinataX': '72137', 'GeoKoordinataY': '511390', 'ZaporednaStevilkaOsebeVPN': '14837001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '37', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'NOVO MESTO', 'Drzavljanstvo': '', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'NE', 'VozniskiStazVLetih': '14', 'VozniskiStazVMesecih': '10', 'VrednostAlkotesta': '0', 'VrednostStrokovnegaPregleda': '1.47', 'Gostota prometa': '0'}
# {'\ufeffZaporednaStevilkaPN': '14861', 'KlasifikacijaNesrece': 'S HUDO TELESNO POŠKODBO', 'UpravnaEnotaStoritve': 'NOVA GORICA', 'DatumPN': '31.12.2020', 'UraPN': '19.okt', 'VNaselju': 'NE', 'Lokacija': 'CESTA', 'VrstaCesteNaselja': 'REGIONALNA CESTA II. REDA', 'SifraCesteNaselja': '402', 'TekstCesteNaselja': 'SOLKAN - GONJAČE - NEBLO', 'SifraOdsekaUlice': '1465', 'TekstOdsekaUlice': 'GONJAČE-DOBROVO', 'StacionazaDogodka': '2600', 'OpisKraja': 'CESTA', 'VzrokNesrece': 'NEPRAVILNA STRAN / SMER VOŽNJE', 'TipNesrece': 'ČELNO TRČENJE', 'VremenskeOkoliscine': 'OBLAČNO', 'StanjePrometa': 'NORMALEN', 'StanjeVozisca': 'SUHO', 'VrstaVozisca': 'ZGLAJEN ASFALT / BETON', 'GeoKoordinataX': '96969', 'GeoKoordinataY': '387491', 'ZaporednaStevilkaOsebeVPN': '14861001', 'Povzrocitelj': 'POVZROČITELJ', 'Starost': '33', 'Spol': 'MOŠKI', 'UEStalnegaPrebivalisca': 'NOVA GORICA', 'Drzavljanstvo': 'SLOVENIJA', 'PoskodbaUdelezenca': 'HUDA TELESNA POŠKODBA', 'VrstaUdelezenca': 'VOZNIK OSEBNEGA AVTOMOBILA', 'UporabaVarnostnegaPasu': 'DA', 'VozniskiStazVLetih': '4', 'VozniskiStazVMesecih': '7', 'VrednostAlkotesta': '0.86', 'VrednostStrokovnegaPregleda': '1.8', 'Gostota prometa': 'nad 1000'}
# {'do 1000': 349,
#  'nad 5000': 192,
#  'nad 10000': 215,
#  '0': 611,
#  'nad 1000': 246,
#  'nad 20000': 373}
